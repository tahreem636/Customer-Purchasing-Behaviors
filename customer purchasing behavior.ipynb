# %% [markdown]
# <a href="https://colab.research.google.com/github/tahreem636/Customer-Purchasing-Behaviors/blob/main/customer%20purchasing%20behavior.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.environ['KAGGLE_CONFIG_DIR']='/CONTENT/'

# %%
# !kaggle datasets download -d hanaksoy/customer-purchasing-behaviors
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/hanaksoy/customer-purchasing-behaviors
# License(s): CC0-1.0
# ...
#   0% 0.00/1.39k [00:00<?, ?B/s]
# 100% 1.39k/1.39k [00:00<00:00, 3.36MB/s]

# %%
import pandas as pd
df = pd.read_csv('/content/customer-purchasing-behaviors.zip')
df
# Out:
#      user_id  age  annual_income  purchase_amount  loyalty_score region  \
# 0          1   25          45000              200            4.5  North
# 1          2   34          55000              350            7.0  South
# 2          3   45          65000              500            8.0   West
# 3          4   22          30000              150            3.0   East
# 4          5   29          47000              220            4.8  North
# ..       ...  ...            ...              ...            ...    ...
# 233      234   40          60000              450            7.2   West
# 234      235   38          59000              430            6.9  North
# 235      236   54          74000              630            9.4  South
# 236      237   32          52000              360            5.8   West
# 237      238   31          51000              340            5.6  North
#
#      purchase_frequency
# 0                    12
# 1                    18
# 2                    22
# ...
